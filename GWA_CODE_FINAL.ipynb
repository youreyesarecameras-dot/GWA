# %% [markdown]
# <a href="https://colab.research.google.com/github/youreyesarecameras-dot/GWA/blob/main/GWA_CODE_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
quarter = 0
while quarter < 1 or quarter > 4:
  quarter = int(input("Which quarter are you entering grades for? "))
  if quarter < 1 or quarter > 4:
    print("Invalid quarter. Please enter 1 to 4.")
  if quarter == 1 or quarter == 2 or quarter == 3 or quarter == 4:
    break

def gwacalc (integratedscience_grade1, mathematics_grade1, computerscience_grade1, english_grade1, filipino_grade1, socialscience_grade1, pehm_grade1, adtech_grade1):
  return round(((integratedscience_grade1 * (1.7)) + (mathematics_grade1 * (1.7)) + computerscience_grade1 + (english_grade1 * (1.3)) + filipino_grade1 + socialscience_grade1 + pehm_grade1 + adtech_grade1) / 9.7, 2)

if quarter == 1:

  validgrades = [1.00, 1.25, 1.50, 1.75, 2.00, 2.25, 2.50, 2.75, 3.00, 4.00, 5.00]

  integratedscience_grade1 = 0
  while integratedscience_grade1 < 1 or integratedscience_grade1 > 0:
    integratedscience_grade1 = float(input("What is your grade for Integrated Science? "))
    if integratedscience_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if integratedscience_grade1 in validgrades:
      break

  mathematics_grade1 = 0
  while mathematics_grade1 < 1 or mathematics_grade1 > 0:
    mathematics_grade1 = float(input(" What is your grade for Mathematics? "))
    if mathematics_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if mathematics_grade1 in validgrades:
      break

  computerscience_grade1 = 0
  while computerscience_grade1 < 1 or computerscience_grade1 > 0:
    computerscience_grade1 = float(input(" What is your grade for Computer Science? "))
    if computerscience_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if computerscience_grade1 in validgrades:
      break

  english_grade1 = 0
  while english_grade1 < 1 or english_grade1 > 0:
    english_grade1 = float(input(" What is your grade for English? "))
    if english_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if english_grade1 in validgrades:
      break

  filipino_grade1 = 0
  while filipino_grade1 < 1 or filipino_grade1 > 0:
    filipino_grade1 = float(input(" What is your grade for Filipino? "))
    if filipino_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if filipino_grade1 in validgrades:
      break

  socialscience_grade1 = 0
  while socialscience_grade1 < 1 or socialscience_grade1 > 0:
    socialscience_grade1 = float(input(" What is your grade for Social Science? "))
    if socialscience_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if socialscience_grade1 in validgrades:
      break

  pehm_grade1 = 0
  while pehm_grade1 < 1 or pehm_grade1 > 0:
    pehm_grade1 = float(input(" What is your grade for PEHM (Physical Education Health Music)? "))
    if pehm_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if pehm_grade1 in validgrades:
      break

  adtech_grade1 = 0
  while adtech_grade1 < 1 or adtech_grade1 > 0:
    adtech_grade1 = float(input(" What is your grade for ADTECH? "))
    if adtech_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if adtech_grade1 in validgrades:
      break

  #Old code, remove "#" if needed
  #gwa1 = ((integratedscience_grade1 * (1.7)) + (mathematics_grade1 * (1.7)) + computerscience_grade1 + (english_grade1 * (1.3)) + filipino_grade1 + socialscience_grade1 + pehm_grade1 + adtech_grade1) / 9.7
  print("FIRST QUARTER RESULT ")
  print(gwacalc(integratedscience_grade1, mathematics_grade1, computerscience_grade1, english_grade1, filipino_grade1, socialscience_grade1, pehm_grade1, adtech_grade1))

if quarter == 2:

  validgrades = [1.00, 1.25, 1.50, 1.75, 2.00, 2.25, 2.50, 2.75, 3.00, 4.00, 5.00]

  integratedscience_grade1 = 0
  while integratedscience_grade1 < 1 or integratedscience_grade1 > 0:
    integratedscience_grade1 = float(input("What is your grade for Integrated Science? "))
    if integratedscience_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if integratedscience_grade1 in validgrades:
      break

  mathematics_grade1 = 0
  while mathematics_grade1 < 1 or mathematics_grade1 > 0:
    mathematics_grade1 = float(input(" What is your grade for Mathematics? "))
    if mathematics_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if mathematics_grade1 in validgrades:
      break

  computerscience_grade1 = 0
  while computerscience_grade1 < 1 or computerscience_grade1 > 0:
    computerscience_grade1 = float(input(" What is your grade for Computer Science? "))
    if computerscience_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if computerscience_grade1 in validgrades:
      break

  english_grade1 = 0
  while english_grade1 < 1 or english_grade1 > 0:
    english_grade1 = float(input(" What is your grade for English? "))
    if english_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if english_grade1 in validgrades:
      break

  filipino_grade1 = 0
  while filipino_grade1 < 1 or filipino_grade1 > 0:
    filipino_grade1 = float(input(" What is your grade for Filipino? "))
    if filipino_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if filipino_grade1 in validgrades:
      break

  socialscience_grade1 = 0
  while socialscience_grade1 < 1 or socialscience_grade1 > 0:
    socialscience_grade1 = float(input(" What is your grade for Social Science? "))
    if socialscience_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if socialscience_grade1 in validgrades:
      break

  pehm_grade1 = 0
  while pehm_grade1 < 1 or pehm_grade1 > 0:
    pehm_grade1 = float(input(" What is your grade for PEHM (Physical Education Health Music)? "))
    if pehm_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if pehm_grade1 in validgrades:
      break

  adtech_grade1 = 0
  while adtech_grade1 < 1 or adtech_grade1 > 0:
    adtech_grade1 = float(input(" What is your grade for ADTECH? "))
    if adtech_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if adtech_grade1 in validgrades:
      break



#old code, remove "#" if needed
  #integratedscience_final = (integratedscience_grade1 * (1/3)) + ((integratedscience_grade2 * (1.7)) * (2/3))
  #mathematics_final = (mathematics_grade1 * (1/3)) + ((mathematics_grade2 * (1.7)) * (2/3))
  #computerscience_final = (computerscience_grade1 * (1/3)) + (computerscience_grade2 * (2/3))
  #english_final = (english_grade1 * (1/3)) + ((english_grade2 * (1.3)) * (2/3))
  #filipino_final = (filipino_grade1 * (1/3)) + (filipino_grade2 * (2/3))
  #socialscience_final = (socialscience_grade1 * (1/3)) + (socialscience_grade2 * (2/3))
  #pehm_final = (pehm_grade1 * (1/3)) + (pehm_grade2 * (2/3))
  #adtech_final = (adtech_grade1 * (1/3)) + (adtech_grade2 * (2/3))

  #gwa2 = (integratedscience_final + mathematics_final + computerscience_final + english_final + filipino_final + socialscience_final + pehm_final + adtech_final) / 8
  #gwa2 = ((integratedscience_grade2 * (1.7)) + (mathematics_grade2 * (1.7)) + computerscience_grade2 + (english_grade2 * (1.3)) + filipino_grade2 + socialscience_grade2 + pehm_grade2 + adtech_grade2) / 9.7

  print("SECOND QUARTER RESULT")
  print(gwacalc(integratedscience_grade1, mathematics_grade1, computerscience_grade1, english_grade1, filipino_grade1, socialscience_grade1, pehm_grade1, adtech_grade1))

if quarter == 3:

  validgrades = [1.00, 1.25, 1.50, 1.75, 2.00, 2.25, 2.50, 2.75, 3.00, 4.00, 5.00]

  integratedscience_grade1 = 0
  while integratedscience_grade1 < 1 or integratedscience_grade1 > 0:
    integratedscience_grade1 = float(input("What is your grade for Integrated Science? "))
    if integratedscience_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if integratedscience_grade1 in validgrades:
      break

  mathematics_grade1 = 0
  while mathematics_grade1 < 1 or mathematics_grade1 > 0:
    mathematics_grade1 = float(input(" What is your grade for Mathematics? "))
    if mathematics_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if mathematics_grade1 in validgrades:
      break

  computerscience_grade1 = 0
  while computerscience_grade1 < 1 or computerscience_grade1 > 0:
    computerscience_grade1 = float(input(" What is your grade for Computer Science? "))
    if computerscience_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if computerscience_grade1 in validgrades:
      break

  english_grade1 = 0
  while english_grade1 < 1 or english_grade1 > 0:
    english_grade1 = float(input(" What is your grade for English? "))
    if english_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if english_grade1 in validgrades:
      break

  filipino_grade1 = 0
  while filipino_grade1 < 1 or filipino_grade1 > 0:
    filipino_grade1 = float(input(" What is your grade for Filipino? "))
    if filipino_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if filipino_grade1 in validgrades:
      break

  socialscience_grade1 = 0
  while socialscience_grade1 < 1 or socialscience_grade1 > 0:
    socialscience_grade1 = float(input(" What is your grade for Social Science? "))
    if socialscience_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if socialscience_grade1 in validgrades:
      break

  pehm_grade1 = 0
  while pehm_grade1 < 1 or pehm_grade1 > 0:
    pehm_grade1 = float(input(" What is your grade for PEHM (Physical Education Health Music)? "))
    if pehm_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if pehm_grade1 in validgrades:
      break

  adtech_grade1 = 0
  while adtech_grade1 < 1 or adtech_grade1 > 0:
    adtech_grade1 = float(input(" What is your grade for ADTECH? "))
    if adtech_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if adtech_grade1 in validgrades:
      break



#old code, remove "#" if needed
  #integratedscience_final3 = (integratedscience_grade2 * (1/3)) + ((integratedscience_grade3 * (1.7)) * (2/3))
  #mathematics_final3 = (mathematics_grade2 * (1/3)) + ((mathematics_grade3 * (1.7)) * (2/3))
  #computerscience_final3 = (computerscience_grade2 * (1/3)) + (computerscience_grade3 * (2/3))
  #english_final3 = (english_grade2 * (1/3)) + ((english_grade3 * (1.3)) * (2/3))
  #filipino_final3 = (filipino_grade2 * (1/3)) + (filipino_grade3 * (2/3))
  #socialscience_final3 = (socialscience_grade2 * (1/3)) + (socialscience_grade3 * (2/3))
  #pehm_final3 = (pehm_grade2 * (1/3)) + (pehm_grade3 * (2/3))
  #adtech_final3 = (adtech_grade2 * (1/3)) + (adtech_grade3 * (2/3))

  #gwa3 = (integratedscience_final3 + mathematics_final3 + computerscience_final3 + english_final3 + filipino_final3 + socialscience_final3 + pehm_final3 + adtech_final3) / 8
  #gwa3 = ((integratedscience_grade3 * (1.7)) + (mathematics_grade3 * (1.7)) + computerscience_grade3 + (english_grade3 * (1.3)) + filipino_grade3 + socialscience_grade3 + pehm_grade3 + adtech_grade3) / 9.7

  print("THIRD QUARTER RESULT")
  print(gwacalc(integratedscience_grade1, mathematics_grade1, computerscience_grade1, english_grade1, filipino_grade1, socialscience_grade1, pehm_grade1, adtech_grade1))





if quarter == 4:

  validgrades = [1.00, 1.25, 1.50, 1.75, 2.00, 2.25, 2.50, 2.75, 3.00, 4.00, 5.00]

  integratedscience_grade1 = 0
  while integratedscience_grade1 < 1 or integratedscience_grade1 > 0:
    integratedscience_grade1 = float(input("What is your grade for Integrated Science? "))
    if integratedscience_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if integratedscience_grade1 in validgrades:
      break

  mathematics_grade1 = 0
  while mathematics_grade1 < 1 or mathematics_grade1 > 0:
    mathematics_grade1 = float(input(" What is your grade for Mathematics? "))
    if mathematics_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if mathematics_grade1 in validgrades:
      break

  computerscience_grade1 = 0
  while computerscience_grade1 < 1 or computerscience_grade1 > 0:
    computerscience_grade1 = float(input(" What is your grade for Computer Science? "))
    if computerscience_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if computerscience_grade1 in validgrades:
      break

  english_grade1 = 0
  while english_grade1 < 1 or english_grade1 > 0:
    english_grade1 = float(input(" What is your grade for English? "))
    if english_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if english_grade1 in validgrades:
      break

  filipino_grade1 = 0
  while filipino_grade1 < 1 or filipino_grade1 > 0:
    filipino_grade1 = float(input(" What is your grade for Filipino? "))
    if filipino_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if filipino_grade1 in validgrades:
      break

  socialscience_grade1 = 0
  while socialscience_grade1 < 1 or socialscience_grade1 > 0:
    socialscience_grade1 = float(input(" What is your grade for Social Science? "))
    if socialscience_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if socialscience_grade1 in validgrades:
      break

  pehm_grade1 = 0
  while pehm_grade1 < 1 or pehm_grade1 > 0:
    pehm_grade1 = float(input(" What is your grade for PEHM (Physical Education Health Music)? "))
    if pehm_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if pehm_grade1 in validgrades:
      break

  adtech_grade1 = 0
  while adtech_grade1 < 1 or adtech_grade1 > 0:
    adtech_grade1 = float(input(" What is your grade for ADTECH? "))
    if adtech_grade1 not in validgrades:
      print("Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00")
    if adtech_grade1 in validgrades:
      break



#old code, remove "#" if needed
  #integratedscience_final4 = (integratedscience_grade3 * (1/3)) + ((integratedscience_grade4 * (1.7)) * (2/3))
  #mathematics_final4 = (mathematics_grade3 * (1/3)) + ((mathematics_grade4 * (1.7)) * (2/3))
  #computerscience_final4 = (computerscience_grade3 * (1/3)) + (computerscience_grade4 * (2/3))
  #english_final4 = (english_grade3 * (1/3)) + ((english_grade4 * (1.3)) * (2/3))
  #filipino_final4 = (filipino_grade3 * (1/3)) + (filipino_grade4 * (2/3))
  #socialscience_final4 = (socialscience_grade3 * (1/3)) + (socialscience_grade4 * (2/3))
  #pehm_final4 = (pehm_grade3 * (1/3)) +1. (pehm_grade4 * (2/3))
  #adtech_final4 = (adtech_grade3 * (1/3)) + (adtech_grade4 * (2/3))

  #gwa4 = (integratedscience_final4 + mathematics_final4 + computerscience_final4 + english_final4 + filipino_final4 + socialscience_final4 + pehm_final4 + adtech_final4) / 8
  #gwa4 = ((integratedscience_grade4 * (1.7)) + (mathematics_grade4 * (1.7)) + computerscience_grade4 + (english_grade4 * (1.3)) + filipino_grade4 + socialscience_grade4 + pehm_grade4 + adtech_grade4) / 9.7

  print("FOURTH QUARTER RESULT")
  print(gwacalc(integratedscience_grade1, mathematics_grade1, computerscience_grade1, english_grade1, filipino_grade1, socialscience_grade1, pehm_grade1, adtech_grade1))

  if gwacalc(integratedscience_grade1, mathematics_grade1, computerscience_grade1, english_grade1, filipino_grade1, socialscience_grade1, pehm_grade1, adtech_grade1) == 1.50 or gwacalc(integratedscience_grade1, mathematics_grade1, computerscience_grade1, english_grade1, filipino_grade1, socialscience_grade1, pehm_grade1, adtech_grade1) < 1.50:
    print("Congratulations, you got DL!")
  if gwacalc(integratedscience_grade1, mathematics_grade1, computerscience_grade1, english_grade1, filipino_grade1, socialscience_grade1, pehm_grade1, adtech_grade1) > 1.50 and gwacalc(integratedscience_grade1, mathematics_grade1, computerscience_grade1, english_grade1, filipino_grade1, socialscience_grade1, pehm_grade1, adtech_grade1) < 2.76:
    print("You passed! Altough you didn't get DL")
  if gwacalc(integratedscience_grade1, mathematics_grade1, computerscience_grade1, english_grade1, filipino_grade1, socialscience_grade1, pehm_grade1, adtech_grade1) > 2.75:
    print("You failed, maybe next time")
# Out:
# Which quarter are you entering grades for? 4
# What is your grade for Integrated Science? 1.7
# Invalid code, please round to 1.00 or 1.25 or 1.50 or 1.75 or 2.00 or 2.25 or 2.50 or 2.75 or 3.00 or 4.00 or 5.00
# What is your grade for Integrated Science? 1.75
#  What is your grade for Mathematics? 1.25
#  What is your grade for Computer Science? 1.5
#  What is your grade for English? 1.75
#  What is your grade for Filipino? 1
#  What is your grade for Social Science? 1
#  What is your grade for PEHM (Physical Education Health Music)? 1
#  What is your grade for ADTECH? 1.25
# FOURTH QUARTER RESULT
# 1.35
# Congratulations, you got DL!
